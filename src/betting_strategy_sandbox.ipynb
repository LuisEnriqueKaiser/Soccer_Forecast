# %%
import pandas as pd


# load in the data 
filepath = "/Users/luisenriquekaiser/Documents/soccer_betting_forecast/data/final/merged_data.csv"
data = pd.read_csv(filepath)
data
# Out:
#            home_team       away_team        date  prob_away_mean_base_bayes  \
# 0     Manchester Utd          Fulham  2024-08-16                   0.312910
# 1    Nott'ham Forest     Bournemouth  2024-08-17                   0.416091
# 2           West Ham     Aston Villa  2024-08-17                   0.239062
# 3      Newcastle Utd     Southampton  2024-08-17                   0.255834
# 4            Everton        Brighton  2024-08-17                   0.294978
# ..               ...             ...         ...                        ...
# 276        Liverpool     Southampton  2025-03-08                   0.656715
# 277   Manchester Utd         Arsenal  2025-03-09                   0.468148
# 278        Tottenham     Bournemouth  2025-03-09                   0.120476
# 279          Chelsea  Leicester City  2025-03-09                   0.128725
# 280         West Ham   Newcastle Utd  2025-03-10                   0.533846
#
# ...

# %%
# step 1: identify odds which are lower than the lower credible intervall 
# step 2: check for abitrage
